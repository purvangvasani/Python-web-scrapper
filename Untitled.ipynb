# %%
from multiprocessing import Pool
from requests import get
from json import dump
from os import getcwd
from os import path
from os import mkdir
from tqdm import tqdm
from bs4 import BeautifulSoup

## FUNCTIONS
def getRawHTML(link):
    
    r = get(link, headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    
    return soup

def retrieveServiceData(data):
    
    all = data.find_all('table', {"class": "typetable"})
    
    serviceArr = []
    for item in all[0].find_all('tr'):
        serviceObj = {}
        
        try:
            service = item.find_all('td')[0].find('a', {"class": "link"}).text
            serviceObj['service'] = service
        except:
            service = 'NA'
        
        try:
            desc = item.find_all('td')[1].text.replace("\n", "")
            serviceObj['description'] = desc
        except:
            desc = 'NA'
        
        try:
            postStr = item.find('a', {"class": 'link'})['href']
            link = base_url + postStr
            serviceObj['link'] = link
        except:
            link = 'NA'
    
        if serviceObj:
            serviceArr.append(serviceObj)
    
    fileDir = dirPath +'/service'
    if not path.exists(fileDir):
        mkdir(fileDir)
        
    with open(path.join(fileDir, '') + 'service.json', 'w+') as outfile:
        dump(serviceArr, outfile)
        
    return serviceArr

def retrieveOperationData(link, index):
    
    data = getRawHTML(link)
    
    all = data.find_all('table', {"class": "typetable"})

    operationArr = []
    for item in all[0].find_all('tr'):
        operationOj = {}
        
        try:
            ops = item.find_all('td')[0].find('a', {"class": "link"}).text
            operationOj['operation'] = ops
        except:
            ops = 'NA'
        
        try:
            desc = item.find_all('td')[1].text.replace("\n", "").replace("\u00a0", "")
            operationOj['description'] = desc
        except:
            desc = 'NA'
        
        try:
            postStr = item.find('a', {"class": 'link'})['href']
            link = base_url + serviceArr[index]['service'] + '/v38.2/' + postStr
            link = link.strip()
            operationOj['link'] = link
        except:
            link = 'NA'
    
        if operationOj:
            operationOj['service'] = serviceArr[index]['service']
            operationArr.append(operationOj)
    
    fileDir = dirPath +'/operation'
    if not path.exists(fileDir):
        mkdir(fileDir)
        
    individual_ops_target_dir = fileDir + '/'+ operationOj['service'] +'/'
    if not path.exists(individual_ops_target_dir):
        mkdir(individual_ops_target_dir)
    
    with open(path.join(individual_ops_target_dir, '') + operationOj['service'] + '.json', 'w+') as outfile:
        dump(operationArr, outfile)
    
    return operationArr

def retrieve(hrefName):
    fieldsArr = []
    for i in data:
        for j in i.find_all('td'):
            if j.find('a', {"name": hrefName}):
                fieldsData = (j.find('table', {"class": 'typetable'})).find_all('tr')
                for item in fieldsData:
                    if len(item.find_all('td')) > 2:
                        fieldsObj = {}
                        try:
                            fieldsObj['parameterName'] = item.find_all('td')[0].text.replace("\n", "").replace("\xa0", "")
                        except:
                            fieldsObj['parameterName'] = 'NA'

                        try:
                            fieldsObj['type'] = item.find_all('td')[1].text.replace("\n", "").replace("\xa0", "")
                            if ((item.find_all('td')[1]).find('a')):
                                if ((item.find_all('td')[1]).find('a')).get('href'): 
                                    fieldsObj[item.find_all('td')[1].text.replace("\n", "").replace("\xa0", "")] = retrieve(((item.find_all('td')[1]).find('a')).get('href')[1:])
                        except:
                            fieldsObj['type'] = 'NA'
                            
                        try:
                            fieldsObj['cardinality'] = item.find_all('td')[2].text.replace("\n", "").replace("\xa0", "")
                        except:
                            fieldsObj['cardinality'] = 'NA'
    
                        try:
                            fieldsObj['description'] = item.find_all('td')[3].text.replace("\n", "").replace("\xa0", "")
                        except:
                            fieldsObj['description'] = 'NA'
                            
                        if fieldsObj:
                            fieldsArr.append(fieldsObj)
    
    return fieldsArr

def retrieveFieldData(link, service, operation):
    
    print("=====================")
    print(link)
    
    rawFieldData = getRawHTML(link)    
    ulList = rawFieldData.find_all('ul')[2]
    requesthreflink = ((ulList.find('li')).find('a'))['href'][1:]
    data = rawFieldData.find_all('table')[0].find_all('tr')
    
    xyz = retrieve(requesthreflink)
    
    print("=====================")
    print(service)
    print(operation)
    print(fileDir)
    print(path.join(fileDir, '') + operation + ".json")
    fileDir = dirPath +'/operation/' + service + '/fields'
    if not path.exists(fileDir):
        mkdir(fileDir)
    with open(path.join(fileDir, '') + operation + ".json", "w+") as outfile:
        dump(arr, outfile)
        
    return True

dirPath = getcwd()

base_url = "https://community.workday.com/sites/default/files/file-hosting/productionapi/"

## Service Extraction
rawServiceData = getRawHTML("https://community.workday.com/sites/default/files/file-hosting/productionapi/index.html")
serviceArr = retrieveServiceData(rawServiceData)

    
if __name__ == '__main__':
    pool1 = Pool()
    result_async = [pool1.apply_async(retrieveOperationData, args = (serviceArr[index]['link'].strip(), index, )) for index in
                    range(len(serviceArr))]
    
    result_async = [result_async[id].get() for id in range(len(result_async))]
        
    for id in tqdm(range(len(result_async))):
        print("===========================")
        print(result_async[id][0]['link'].strip())
        result_async1 = [pool1.apply_async(retrieveFieldData, args = (result_async[id][index]['link'].strip(), result_async[id][index]['service'], result_async[id][index]['operation'], )) for index in
                    range(len(result_async[id]))]

# %%
process = [] 
for ops in range(len(result_async)):
    
    result_async1 = [pool1.apply_async(getRawHTML, args = (result_async[ops][index]['link'].strip(), )) for index in
                    range(len(result_async[ops]))]
    
    result_async1 = [result_async1[id].get() for id in range(len(result_async1))]
    process.append(result_async1)
    #result_async1 = [result_async1[id].get() for id in range(len(result_async1))]
    
    #print(len(result_async))
    
    #for index in range(len(result_async[ops])):
        
        #rawFieldData = getRawHTML(result_async[ops][index]['link'].strip())
        
        #ulList = rawFieldData.find_all('ul')[2]
        #requesthreflink = ((ulList.find('li')).find('a'))['href'][1:]
        #data = rawFieldData.find_all('table')[0].find_all('tr')
        
        #arr = retrieveFieldData(requesthreflink)
        
        #rawFieldData = getRawHTML(result_async[ops][index]['link'].strip())
        #ulList = rawFieldData.find_all('ul')[2]
        #requesthreflink = ((ulList.find('li')).find('a'))['href'][1:]
        #data = rawFieldData.find_all('table')[0].find_all('tr')

# %%
## FUNCTIONS
def getRawHTML(link):
    
    r = get(link, headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    
    return soup

def retrieveServiceData(data):
    
    all = data.find_all('table', {"class": "typetable"})
    
    serviceArr = []
    for item in all[0].find_all('tr'):
        serviceObj = {}
        
        try:
            service = item.find_all('td')[0].find('a', {"class": "link"}).text
            serviceObj['service'] = service
        except:
            service = 'NA'
        
        try:
            desc = item.find_all('td')[1].text.replace("\n", "")
            serviceObj['description'] = desc
        except:
            desc = 'NA'
        
        try:
            postStr = item.find('a', {"class": 'link'})['href']
            link = base_url + postStr
            serviceObj['link'] = link
        except:
            link = 'NA'
    
        if serviceObj:
            serviceArr.append(serviceObj)
    
    fileDir = dirPath +'/service'
    if not path.exists(fileDir):
        mkdir(fileDir)
        
    with open(path.join(fileDir, '') + 'service.json', 'w+') as outfile:
        dump(serviceArr, outfile)
        
    return serviceArr

def retrieveOperationData(data, index):
    
    all = data.find_all('table', {"class": "typetable"})

    operationArr = []
    for item in all[0].find_all('tr'):
        operationOj = {}
        
        try:
            ops = item.find_all('td')[0].find('a', {"class": "link"}).text
            operationOj['operation'] = ops
        except:
            ops = 'NA'
        
        try:
            desc = item.find_all('td')[1].text.replace("\n", "").replace("\u00a0", "")
            operationOj['description'] = desc
        except:
            desc = 'NA'
        
        try:
            postStr = item.find('a', {"class": 'link'})['href']
            link = base_url + serviceArr[index]['service'] + '/v38.2/' + postStr
            link = link.strip()
            operationOj['link'] = link
        except:
            link = 'NA'
    
        if operationOj:
            operationOj['service'] = serviceArr[index]['service']
            operationArr.append(operationOj)
    
    fileDir = dirPath +'/operation'
    if not path.exists(fileDir):
        mkdir(fileDir)
        
    individual_ops_target_dir = fileDir + '/'+ serviceArr[index]['service'] +'/'
    if not path.exists(individual_ops_target_dir):
        mkdir(individual_ops_target_dir)
    
    with open(path.join(individual_ops_target_dir, '') + serviceArr[index]['service'] + '.json', 'w+') as outfile:
        dump(operationArr, outfile)
    
    return operationArr

def retrieve(hrefName, data):
    fieldsArr = []
    for i in data:
        for j in i.find_all('td'):
            if j.find('a', {"name": hrefName}):
                fieldsData = (j.find('table', {"class": 'typetable'})).find_all('tr')
                for item in fieldsData:
                    if len(item.find_all('td')) > 2:
                        fieldsObj = {}
                        try:
                            fieldsObj['parameterName'] = item.find_all('td')[0].text.replace("\n", "").replace("\xa0", "")
                        except:
                            fieldsObj['parameterName'] = 'NA'

                        try:
                            fieldsObj['type'] = item.find_all('td')[1].text.replace("\n", "").replace("\xa0", "")
                            if ((item.find_all('td')[1]).find('a')):
                                if ((item.find_all('td')[1]).find('a')).get('href'): 
                                    fieldsObj[item.find_all('td')[1].text.replace("\n", "").replace("\xa0", "")] = retrieve(((item.find_all('td')[1]).find('a')).get('href')[1:], data)
                        except:
                            fieldsObj['type'] = 'NA'
                            
                        try:
                            fieldsObj['cardinality'] = item.find_all('td')[2].text.replace("\n", "").replace("\xa0", "")
                        except:
                            fieldsObj['cardinality'] = 'NA'
    
                        try:
                            fieldsObj['description'] = item.find_all('td')[3].text.replace("\n", "").replace("\xa0", "")
                        except:
                            fieldsObj['description'] = 'NA'
                            
                        if fieldsObj:
                            fieldsArr.append(fieldsObj)
        
    return fieldsArr

def retrieveFieldData(link, service, operation):
    
    rawFieldData = getRawHTML(link)    
    ulList = rawFieldData.find_all('ul')[2]
    requesthreflink = ((ulList.find('li')).find('a'))['href'][1:]
    data = rawFieldData.find_all('table')[0].find_all('tr')
    xyz = retrieve(requesthreflink, data)

    if service:
        fileDir = dirPath +'/operation/' + service + '/fields'
        if not path.exists(fileDir):
            mkdir(fileDir)
        
        if operation:
            with open(path.join(fileDir, '') + operation + ".json", "w+") as outfile:
                dump(xyz, outfile)
        else:
            print("NOT OPERATION")
    else:
        print("NOT SERVICE")
    
        
    return True


from requests import get
from json import dump
from os import getcwd
from os import path
from os import mkdir
from tqdm import tqdm
from bs4 import BeautifulSoup
from multiprocessing import Pool, Process
import threading

dirPath = getcwd()

base_url = "https://community.workday.com/sites/default/files/file-hosting/productionapi/"

## Service Extraction
rawServiceData = getRawHTML("https://community.workday.com/sites/default/files/file-hosting/productionapi/index.html")
serviceArr = retrieveServiceData(rawServiceData)
pool=Pool(processes=5)
process = []
threads = []
## Operations Extraction
for index in tqdm(range(len(serviceArr))):
    rawOperationData = getRawHTML(serviceArr[index]['link'].strip())
    operationArr = retrieveOperationData(rawOperationData, index)
    
    ## Fields of Operation Extraction
    for id in range(len(operationArr)):
        #pool.apply_async(retrieveFieldData,(operationArr[id]['link'].strip(), operationArr[id]['service'], operationArr[id]['operation'],))
        t = threading.Thread(target=retrieveFieldData, args=(operationArr[id]['link'].strip(), operationArr[id]['service'], operationArr[id]['operation'],))
        #threads.append(t)
        #t.start()
        p=Process(target=retrieveFieldData,args=(operationArr[id]['link'].strip(), operationArr[id]['service'], operationArr[id]['operation'],))
        process.append(p)
        #p.start()
# Out:
# 100%|██████████| 49/49 [01:23<00:00,  1.55s/it]

# %%
step_size = 10
initial = 0
x = range(initial, len(process)-1000, step_size)
for p in tqdm(range(initial, len(process)-1000, step_size)):
    #print(range(step_size))
    for step in range(initial, step_size):
        #print(process[step])
        process[step].start()
    
    initial = step_size
    step_size = step_size + 10
    process[p].join()

print("demo")
# Out:
#  51%|█████     | 83/163 [13:11<13:15,  9.94s/it]  Process Process-3462:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3463:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3470:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3475:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3461:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3478:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3468:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-3474:
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Traceback (most recent call last):
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3477:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3473:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3469:
# Traceback (most recent call last):
# Process Process-3476:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  52%|█████▏    | 84/163 [13:25<14:38, 11.11s/it]Process Process-3472:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3471:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3485:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3479:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  52%|█████▏    | 85/163 [13:27<10:55,  8.41s/it]Process Process-3480:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3483:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3482:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3487:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process Process-3486:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3484:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Process Process-3488:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3496:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3490:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3491:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3494:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3492:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3498:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3495:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3497:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3481:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3493:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3489:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  53%|█████▎    | 86/163 [13:47<15:07, 11.78s/it]Process Process-3503:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Process Process-3501:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3507:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process Process-3506:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3508:
# Process Process-3500:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3504:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process Process-3502:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process Process-3505:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3499:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  53%|█████▎    | 87/163 [13:50<11:37,  9.17s/it]Process Process-3512:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3513:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3509:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  54%|█████▍    | 88/163 [13:52<08:45,  7.01s/it]Process Process-3511:
# Traceback (most recent call last):
# Process Process-3516:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-3517:
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3518:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3514:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3510:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process Process-3520:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3521:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3523:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3527:
# Traceback (most recent call last):
# Process Process-3526:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Process Process-3519:
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Traceback (most recent call last):
# Process Process-3524:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  55%|█████▍    | 89/163 [13:55<07:06,  5.76s/it]FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3528:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3522:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3525:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3536:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3531:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3537:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3533:
# Traceback (most recent call last):
# Process Process-3535:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-3534:
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3529:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  55%|█████▌    | 90/163 [13:58<06:08,  5.05s/it]Process Process-3532:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3515:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3530:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3542:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3543:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3548:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3539:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  56%|█████▌    | 91/163 [14:01<05:15,  4.38s/it]Process Process-3544:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3545:
# Traceback (most recent call last):
# Process Process-3538:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3541:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3549:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  56%|█████▋    | 92/163 [14:04<04:35,  3.88s/it]Process Process-3550:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3557:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3556:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# ...
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3604:
# Process Process-3606:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3599:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process Process-3600:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  60%|█████▉    | 97/163 [14:48<07:10,  6.52s/it]FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3592:
# Traceback (most recent call last):
# Process Process-3607:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process Process-3603:
# Process Process-3605:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3608:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-3601:
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Traceback (most recent call last):
# Process Process-3602:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3611:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3610:
# Traceback (most recent call last):
# Process Process-3609:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  60%|██████    | 98/163 [14:50<05:38,  5.21s/it]Process Process-3614:
# Traceback (most recent call last):
# Process Process-3616:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Traceback (most recent call last):
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-3618:
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Traceback (most recent call last):
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3615:
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3617:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3621:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3622:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3620:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-3624:
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Traceback (most recent call last):
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-3619:
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Traceback (most recent call last):
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
#  61%|██████    | 99/163 [14:53<04:50,  4.53s/it]Process Process-3627:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# Process Process-3628:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3625:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'
# Process Process-3623:
# Traceback (most recent call last):
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/purvang/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-11-70ef4189f725>", line 142, in retrieveFieldData
#     mkdir(fileDir)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/purvang/project/py/python-projects/Applications/web-scrapper/operation/Human_Resources/fields'

# %%
for x in threads:
    print(x.isAlive())
