# %%
import requests
import pandas
from bs4 import BeautifulSoup

df = pandas.DataFrame(columns=['Price', 'Address', '# of Beds', '# of Baths', 'Size', 'Lot Size'])

r = requests.get("http://pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/", 
                 headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content

soup = BeautifulSoup(c, "html.parser")

all = soup.find_all('div', {"class": "propertyRow"})

# %%
for item in all:
    price = item.find('h4', {"class": 'propPrice'}).text.replace("\n", "").replace(" ", "")
    add1 = item.find_all('span', {"class": 'propAddressCollapse'})[0].text
    add2 = item.find_all('span', {"class": 'propAddressCollapse'})[1].text
    fullAdd = add1 + add2
    try:
        noOfBed = item.find('span', {"class": 'infoBed'}).find('b').text
    except:
        noOfBed = 'NA'
    try:
        noOfBath = item.find('span', {"class": 'infoValueFullBath'}).find('b').text
    except:
        noOfBath = 'NA'
    try:
        size = item.find('span', {"class": 'infoSqFt'}).find('b').text + ' Sq. Ft'
    except:
        size = 'NA'
    
    lotSize = 'NA'
    for col in item.find_all('div', {'class': 'columnGroup'}):
        for feature_group, feature_name in zip(col.find_all('span', {"class":'featureGroup'}), col.find_all('span', {"class":'featureName'})):
            if 'Lot Size' in feature_group.text:
                lotSize = feature_name.text

    df = df.append({"Price": price, "Address": fullAdd, "# of Beds": noOfBed, "# of Baths": noOfBath, "Size": size, "Lot Size": lotSize}, ignore_index=True)
    
df.to_csv("Data.csv")

# %%
df
# Out:
#       Price                                      Address # of Beds # of Baths  \
# 0  $725,000              0 GatewayRock Springs, WY 82901        NA         NA
# 1  $452,900  1003 Winchester Blvd.Rock Springs, WY 82901         4          4
# 2  $396,900          600 TalladegaRock Springs, WY 82901         5          3
# 3  $389,900     3239 Spearhead WayRock Springs, WY 82901         4          3
# 4  $254,000     522 Emerald StreetRock Springs, WY 82901         3          3
# 5  $252,900   1302 Veteran's DriveRock Springs, WY 82901         4          2
# 6  $210,000       1021 Cypress CirRock Springs, WY 82901         4          3
# 7  $209,000         913 Madison DrRock Springs, WY 82901         3          2
# 8  $199,900      1344 Teton StreetRock Springs, WY 82901         3          2
# 9  $196,900         4 Minnies LaneRock Springs, WY 82901         3          2
#
#            Size          Lot Size
# 0            NA                NA
# 1            NA        0.21 Acres
# 2  3,154 Sq. Ft                NA
# 3  3,076 Sq. Ft  Under 1/2 Acre,
# 4  1,172 Sq. Ft  Under 1/2 Acre,
# 5  1,932 Sq. Ft        0.27 Acres
# 6  1,676 Sq. Ft  Under 1/2 Acre,
# 7  1,344 Sq. Ft  Under 1/2 Acre,
# 8  1,920 Sq. Ft  Under 1/2 Acre,
# 9  1,664 Sq. Ft        2.02 Acres
